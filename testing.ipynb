# %%
import numpy as np

# %%
path = "data/my_dataset/train_scene_1.npy"

# %%
data = np.load(path)
data[0]
# Out:
# array([1.350e-01, 1.161e+00, 9.740e-01, 1.820e+02, 1.000e+02, 6.300e+01,
#        1.200e+01])

# %%
coords = data[:, :3]
color = data[:, 3:6]
segment = data[:, 6].astype(np.int32)
coords[0], color[0], segment[0]
# Out:
# (array([0.135, 1.161, 0.974]), array([182., 100.,  63.]), np.int32(12))

# %%
root = "data/my_dataset/train/scene_1"
np.save(root + "/coords.npy", coords)
np.save(root + "/color.npy", color)
np.save(root + "/segment.npy", segment)
